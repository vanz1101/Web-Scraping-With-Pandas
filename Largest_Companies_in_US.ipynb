# %% [markdown]
# <a href="https://colab.research.google.com/github/vanz1101/Web-Scraping-With-Pandas/blob/main/Largest_Companies_in_US.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import pandas library as pd

import pandas as pd

# %%
## Passing in the url for the website that contains the data

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

# %%
## read the url using .read_html() function and storing the info in a variable table

table = pd.read_html(url, flavor = 'bs4')
table
# Out:
# [    0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#      Rank                      Name                    Industry  \
#  0      1                   Walmart                      Retail
#  1      2                    Amazon  Retail and cloud computing
#  2      3                ExxonMobil          Petroleum industry
#  3      4                     Apple        Electronics industry
#  4      5        UnitedHealth Group                  Healthcare
#  ..   ...                       ...                         ...
#  95    96                  Best Buy                      Retail
#  96    97      Bristol-Myers Squibb     Pharmaceutical industry
#  97    98           United Airlines                     Airline
#  98    99  Thermo Fisher Scientific      Laboratory instruments
#  99   100                  Qualcomm                  Technology
#
#      Revenue (USD millions)  Revenue growth  Employees             Headquarters
# ...

# %%
## Saving the wanted table as a dataframe

df = table[1]
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#     Revenue (USD millions)  Revenue growth  Employees             Headquarters
# 0                   611289             NaN    2100000    Bentonville, Arkansas
# ...

# %%
## saving the dataframe to the computer as a csv file.
df.to_csv('largest US companies.csv')

# %%
## The visualization were used to give meaning to the scraped table

# %%
from matplotlib import pyplot as plt
df['Revenue (USD millions)'].plot(kind='hist', bins=20, title='Revenue (USD millions)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Rank']
  ys = series['Employees']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Rank', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Rank')
_ = plt.ylabel('Employees')

# %%
from matplotlib import pyplot as plt
df['Employees'].plot(kind='line', figsize=(8, 4), title='Employees')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Revenue (USD millions)'].plot(kind='line', figsize=(8, 4), title='Revenue (USD millions)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Rank', y='Revenue (USD millions)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
